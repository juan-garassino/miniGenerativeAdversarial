# %%
from miniGan.predict import predict
import matplotlib.pyplot as plt
predict("G_epoch_0", plot=True)
# Out:
# ✅Loaded model from /home/juan-garassino/code/juan-garassino/miniSeries/miniGan...

# %%
predict("G_epoch_0", plot=True)
# Out:
# ✅Loaded model from /home/juan-garassino/code/juan-garassino/miniSeries/miniGan...
